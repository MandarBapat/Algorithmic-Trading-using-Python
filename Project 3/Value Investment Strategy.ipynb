# %%
import numpy as np
import pandas as pd
import xlsxwriter
import requests
from scipy import stats
import math

# %%
stocks = pd.read_csv("../Project 1/sp_500_stocks.csv")
stocks
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
IEX_CLOUD_API_TOKEN = 'Tpk_059b97af715d417d9f49f50b51b1c448'
base_url = "https://sandbox.iexapis.com/stable/stock/"
col_names = ["Ticker", "Price", "Price-to-Earnings Ratio"]

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

# %%
symbol_groups = list(chunks(stocks["Ticker"], 100))

symbol_strings = []

final_dataframe = pd.DataFrame(columns = col_names)

for group in symbol_groups:
    symbol_strings.append(','.join(group))

for symbol_string in symbol_strings:
    batch_api_call_url = f"{base_url}market/batch?symbols={symbol_string}&types=quote&token={IEX_CLOUD_API_TOKEN}"
    data = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        if symbol == "WLTW":
            continue
        final_dataframe = final_dataframe.append(
            pd.Series(
                [
                    symbol,
                    data[symbol]["quote"]["latestPrice"],
                    data[symbol]["quote"]["peRatio"]
                ],
                index = col_names
            ),
            ignore_index = True
        )

# %%
final_dataframe
# Out:
#     Ticker   Price Price-to-Earnings Ratio
# 0        A  140.46                   17.62
# 1      AAL   19.26                   -3.93
# 2      AAP  224.30                   23.53
# 3     AAPL  177.32                    29.4
# 4     ABBV  149.11                   35.48
# ..     ...     ...                     ...
# 499    YUM  128.00                   23.99
# 500    ZBH  126.56                   31.25
# 501   ZBRA  449.80                   14.42
# 502   ZION   75.84                    7.25
# 503    ZTS  198.27                   49.59
#
# [504 rows x 3 columns]

# %%
final_dataframe.sort_values("Price-to-Earnings Ratio", inplace=True)
final_dataframe = final_dataframe[final_dataframe["Price-to-Earnings Ratio"] > 0]
final_dataframe = final_dataframe[:50]
final_dataframe.reset_index(drop=True, inplace=True)

# %%
final_dataframe
# Out:
#    Ticker    Price Price-to-Earnings Ratio
# 0       F   18.730                    2.06
# 1     BIO  644.350                     2.3
# 2     SYF   45.750                    3.16
# 3    EBAY   62.420                    3.28
# 4     LEN   94.380                    3.35
# 5     PHM   49.600                    3.35
# 6     COO  403.640                    3.45
# 7     HPE   17.530                     3.5
# 8      DD   83.340                    3.51
# 9     DOW   62.660                    3.67
# 10    HPQ   38.210                    3.68
# 11    WHR  213.730                    3.74
# 12     GM   51.800                    3.83
# 13    NRG   40.650                    3.96
# 14   REGN  659.940                    4.48
# 15    NOC  403.930                    4.51
# 16     CE  163.010                    4.83
# 17   INTC   50.470                    5.04
# 18      L   64.420                     5.1
# 19     VZ   55.150                    5.14
# 20    MPC   79.900                    5.61
# 21    USB   59.160                    5.92
# 22    COF  161.580                    6.01
# 23    LYB  105.940                    6.14
# 24     GS  372.410                    6.15
# 25    PFG   76.510                    6.18
# 26    WBA   49.600                    6.58
# 27      C   70.000                    6.59
# 28    PRU  122.000                    6.72
# 29    HII  183.120                    6.73
# 30    DVA  117.600                    6.75
# 31    OMC   88.500                    6.83
# 32    DHI   87.177                    6.85
# 33    CMS   63.240                    6.88
# 34   VIAC   37.000                       7
# 35    BAC   48.970                    7.02
# 36   ZION   75.840                    7.25
# 37    SNA  221.130                    7.35
# 38    NUE  123.600                    7.41
# 39    AIZ  168.470                    7.57
# 40    UNM   30.440                    7.58
# 41   DISH   32.410                    7.87
# 42    MMM  164.410                     7.9
# 43    DFS  130.770                    7.94
# 44    CMI  225.460                    7.94
# 45   CINF  126.110                    8.04
# 46     FB  226.000                    8.08
# 47    DGX  134.760                    8.11
# 48  CMCSA   50.450                     8.2
# 49    ALK   60.330                     8.2

# %%
def portfolio_input():
    global portfolio_size
    portfolio_size = input("Please enter your portfolio size")
    
    try:
        portfolio_size = int(portfolio_size)
    except ValueError:
        print("The value entered was not a number! Enter again :")
        portfolio_size = input()
        portfolio_size = int(portfolio_size)

# %%
portfolio_input()
# Out:
# Please enter your portfolio size10000000

# %%
position_size = portfolio_size/final_dataframe.shape[0]
position_size
# Out:
# 200000.0

# %%
for row in final_dataframe.index:
    final_dataframe.loc[row, "Number of shares to buy"] = math.floor(position_size/final_dataframe.loc[row, "Price"])

# %%
final_dataframe
# Out:
#    Ticker    Price Price-to-Earnings Ratio  Number of shares to buy
# 0       F   18.730                    2.06                  10678.0
# 1     BIO  644.350                     2.3                    310.0
# 2     SYF   45.750                    3.16                   4371.0
# 3    EBAY   62.420                    3.28                   3204.0
# 4     LEN   94.380                    3.35                   2119.0
# 5     PHM   49.600                    3.35                   4032.0
# 6     COO  403.640                    3.45                    495.0
# 7     HPE   17.530                     3.5                  11409.0
# 8      DD   83.340                    3.51                   2399.0
# 9     DOW   62.660                    3.67                   3191.0
# 10    HPQ   38.210                    3.68                   5234.0
# 11    WHR  213.730                    3.74                    935.0
# 12     GM   51.800                    3.83                   3861.0
# 13    NRG   40.650                    3.96                   4920.0
# 14   REGN  659.940                    4.48                    303.0
# 15    NOC  403.930                    4.51                    495.0
# 16     CE  163.010                    4.83                   1226.0
# 17   INTC   50.470                    5.04                   3962.0
# 18      L   64.420                     5.1                   3104.0
# 19     VZ   55.150                    5.14                   3626.0
# 20    MPC   79.900                    5.61                   2503.0
# 21    USB   59.160                    5.92                   3380.0
# 22    COF  161.580                    6.01                   1237.0
# 23    LYB  105.940                    6.14                   1887.0
# 24     GS  372.410                    6.15                    537.0
# 25    PFG   76.510                    6.18                   2614.0
# 26    WBA   49.600                    6.58                   4032.0
# 27      C   70.000                    6.59                   2857.0
# 28    PRU  122.000                    6.72                   1639.0
# 29    HII  183.120                    6.73                   1092.0
# 30    DVA  117.600                    6.75                   1700.0
# 31    OMC   88.500                    6.83                   2259.0
# 32    DHI   87.177                    6.85                   2294.0
# 33    CMS   63.240                    6.88                   3162.0
# 34   VIAC   37.000                       7                   5405.0
# 35    BAC   48.970                    7.02                   4084.0
# 36   ZION   75.840                    7.25                   2637.0
# 37    SNA  221.130                    7.35                    904.0
# 38    NUE  123.600                    7.41                   1618.0
# 39    AIZ  168.470                    7.57                   1187.0
# 40    UNM   30.440                    7.58                   6570.0
# 41   DISH   32.410                    7.87                   6170.0
# 42    MMM  164.410                     7.9                   1216.0
# 43    DFS  130.770                    7.94                   1529.0
# 44    CMI  225.460                    7.94                    887.0
# 45   CINF  126.110                    8.04                   1585.0
# 46     FB  226.000                    8.08                    884.0
# 47    DGX  134.760                    8.11                   1484.0
# 48  CMCSA   50.450                     8.2                   3964.0
# 49    ALK   60.330                     8.2                   3315.0

# %%
symbol = "AAPL"
batch_api_call_url = f"{base_url}market/batch?symbols={symbol_string}&types=quote,advanced-stats&token={IEX_CLOUD_API_TOKEN}"
data = requests.get(batch_api_call_url).json()
data
# Out:
# {'YUM': {'advanced-stats': {'beta': 0.6761676885386002,
#    'totalCash': 1027019595,
#    'currentDebt': 1356770329,
#    'revenue': 6708040840,
#    'grossProfit': 4904985875,
#    'totalRevenue': 6606873914,
#    'EBITDA': 2267225376,
#    'revenuePerShare': 22.55,
#    'revenuePerEmployee': 190763.79,
#    'debtToEquity': -0.8352170932223473,
#    'profitMargin': 0.25275437423340513,
#    'enterpriseValue': 46443773336,
#    'enterpriseValueToRevenue': 7.46,
#    'priceToSales': 5.9,
#    'priceToBook': -4.79,
#    'forwardPERatio': 25.6313369160017,
#    'pegRatio': 0.4726046651651539,
#    'peHigh': 12.62286734642619,
#    'peLow': 6.535843385072451,
#    'week52highDate': '2021-12-26',
#    'week52lowDate': '2021-02-25',
#    'putCallRatio': 0.893038798389124,
#    'companyName': 'Yum Brands Inc.',
#    'marketcap': 37482468704,
#    'week52high': 143.58,
#    'week52low': 101.82,
#    'week52highSplitAdjustOnly': 141.17,
#    'week52highDateSplitAdjustOnly': '2021-12-23',
#    'week52lowSplitAdjustOnly': 104.59,
#    'week52lowDateSplitAdjustOnly': '2021-02-28',
#    'week52change': 0.1824102598630304,
#    'sharesOutstanding': 303117387,
#    'float': None,
#    'avg10Volume': 2896044,
#    'avg30Volume': 2481618,
#    'day200MovingAvg': 133.5,
#    'day50MovingAvg': 130.78,
#    'employees': 2114,
#    'ttmEPS': 5.42,
#    'ttmDividendRate': 1.538162869897654,
#    'dividendYield': 0.012733545798895953,
#    'nextDividendDate': '2022-02-12',
#    'exDividendDate': '',
#    'nextEarningsDate': '2022-04-14',
#    'peRatio': 22.91536613045332,
#    'maxChangePercent': 6.653029057009418,
#    'year5ChangePercent': 0.9515212056100629,
#    'year2ChangePercent': 0.209406386260542,
#    'year1ChangePercent': 0.1843254309892967,
#    'ytdChangePercent': -0.11568726901964158,
#    'month6ChangePercent': -0.08328608356372214,
#    'month3ChangePercent': -0.02466115295690848,
#    'month1ChangePercent': -0.03241741044502995,
#    'day30ChangePercent': -0.03243328180427281,
#    'day5ChangePercent': -0.015816178687878137},
#   'quote': {'avgTotalVolume': 2457244,
#    'calculationPrice': 'close',
#    'change': 1.7,
#    'changePercent': 0.0132,
#    'close': 0,
#    'closeSource': 'ocailffi',
#    'closeTime': None,
#    'companyName': 'Yum Brands Inc.',
#    'currency': 'USD',
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPrice': None,
#    'extendedPriceTime': None,
#    'high': 0,
#    'highSource': 'dieue rei1n5 ld mtecayp',
#    'highTime': 1680263609514,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexClose': 126,
#    'iexCloseTime': 1698991567159,
#    'iexLastUpdated': 0,
#    'iexMarketPercent': None,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexRealtimePrice': 0,
#    'iexRealtimeSize': 0,
#    'iexVolume': 0,
#    'lastTradeTime': 1672861174077,
#    'latestPrice': 124,
#    'latestSource': 'Close',
#    'latestTime': 'February 15, 2022',
#    'latestUpdate': 1669202688036,
#    'latestVolume': None,
#    'low': 0,
#    'lowSource': 'cn pyt e r1luea5edemiid',
#    'lowTime': 1665136183573,
#    'marketCap': 36301203562,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'open': 0,
#    'openTime': None,
#    'openSource': 'aicfiflo',
#    'peRatio': 24.6,
#    'previousClose': 124.2,
#    'previousVolume': 2707299,
#    'primaryExchange': 'NOGHEWTXECEC .K SOKRI AY NNC',
#    'symbol': 'YUM',
#    'volume': None,
#    'week52High': 144.97,
#    'week52Low': 103.1,
#    'ytdChange': -0.10507454139634191,
#    'isUSMarketOpen': False}},
#  'ZBH': {'advanced-stats': {'beta': 0.7996204071243902,
#    'totalCash': 929644059,
#    'currentDebt': 2947740382,
#    'revenue': 8175069744,
#    'grossProfit': 5680699105,
#    'totalRevenue': 8272020737,
#    'EBITDA': 1879669683,
#    'revenuePerShare': 39.51,
#    'revenuePerEmployee': 439071.59,
#    'debtToEquity': 1.9488766686519297,
#    'profitMargin': 0.10394667834911164,
#    'enterpriseValue': 33419007514,
#    'enterpriseValueToRevenue': 4.25,
#    'priceToSales': 3.26,
#    'priceToBook': 2.1,
#    'forwardPERatio': 19.03646126546454,
#    'pegRatio': 0.04971149546785444,
#    'peHigh': -223.0597678286368,
#    'peLow': -325.9567185899159,
#    'week52highDate': '2021-04-24',
#    'week52lowDate': '2022-02-02',
#    'putCallRatio': 1.429979459633279,
#    'companyName': 'Zimmer Biomet Holdings Inc',
#    'marketcap': 26360480312,
#    'week52high': 185.59,
#    'week52low': 110.46,
#    'week52highSplitAdjustOnly': 181.63,
#    'week52highDateSplitAdjustOnly': '2021-04-16',
#    'week52lowSplitAdjustOnly': 108.85,
#    'week52lowDateSplitAdjustOnly': '2022-02-01',
#    'week52change': -0.2411439129082171,
#    'sharesOutstanding': 214958670,
#    'float': None,
#    'avg10Volume': 2929045,
#    'avg30Volume': 2334796,
#    'day200MovingAvg': 139.6,
#    'day50MovingAvg': 124.84,
#    'employees': 20840,
#    'ttmEPS': 4.04,
#    'ttmDividendRate': 0.977999079926344,
#    'dividendYield': 0.007854410495642446,
#    'nextDividendDate': None,
#    'exDividendDate': '',
#    'nextEarningsDate': '2022-04-30',
#    'peRatio': 31.30104310895885,
#    'maxChangePercent': 0.63019985796149,
#    'year5ChangePercent': 0.08304403074426267,
#    'year2ChangePercent': -0.237449015837126,
#    'year1ChangePercent': -0.24123578018420563,
#    'ytdChangePercent': -0.03896202633094325,
#    'month6ChangePercent': -0.16761701261294723,
#    'month3ChangePercent': -0.071548437252262,
#    'month1ChangePercent': -0.0426666309856826,
#    'day30ChangePercent': -0.04234928229185187,
#    'day5ChangePercent': 0.0189353819777811},
#   'quote': {'avgTotalVolume': 2397827,
#    'calculationPrice': 'close',
#    'change': 5.2,
#    'changePercent': 0.04424,
#    'close': 0,
#    'closeSource': 'cflafioi',
#    'closeTime': None,
#    'companyName': 'Zimmer Biomet Holdings Inc',
#    'currency': 'USD',
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPrice': None,
#    'extendedPriceTime': None,
#    'high': 0,
#    'highSource': 'imuelea5dcede y 1 npitr',
#    'highTime': 1700593972690,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexClose': 123.67,
#    'iexCloseTime': 1724770563793,
#    'iexLastUpdated': 0,
#    'iexMarketPercent': None,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexRealtimePrice': 0,
#    'iexRealtimeSize': 0,
#    'iexVolume': 0,
#    'lastTradeTime': 1712532209627,
#    'latestPrice': 123.13,
#    'latestSource': 'Close',
#    'latestTime': 'February 15, 2022',
#    'latestUpdate': 1685060722408,
#    'latestVolume': None,
#    'low': 0,
#    'lowSource': 'elci i IrtameEXrep ',
#    'lowTime': 1654148266813,
#    'marketCap': 25877204875,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'open': 0,
#    'openTime': None,
#    'openSource': 'foifiacl',
#    'peRatio': 31.98,
#    'previousClose': 122.57,
#    'previousVolume': 1125431,
#    'primaryExchange': 'NWOS REGCK CHANT E. EXNYOKIC',
#    'symbol': 'ZBH',
#    'volume': None,
#    'week52High': 184.58,
#    'week52Low': 109.5,
#    'ytdChange': 0.005660619788651921,
#    'isUSMarketOpen': False}},
#  'ZBRA': {'advanced-stats': {'beta': 1.502485560698507,
#    'totalCash': 690196164,
#    'currentDebt': 3729038031,
#    'revenue': 11467663070,
#    'grossProfit': 5272036369,
#    'totalRevenue': 11592038652,
#    'EBITDA': 2300052164,
#    'revenuePerShare': 221.96,
#    'revenuePerEmployee': 1570654.72,
#    'debtToEquity': 2.18382104468443,
#    'profitMargin': 0.1522887294727371,
#    'enterpriseValue': 24865904750,
#    'enterpriseValueToRevenue': 2.25,
#    'priceToSales': 2.07,
#    'priceToBook': 3.98,
#    'forwardPERatio': 22.47243227805347,
#    'pegRatio': 0.102963561239065,
#    'peHigh': -24.86105657335908,
#    'peLow': -47.10558974827979,
#    'week52highDate': '2021-12-08',
#    'week52lowDate': '2022-02-03',
#    'putCallRatio': 1.2297692803194653,
#    'companyName': 'Zebra Technologies Corp.',
#    'marketcap': 23329700664,
#    'week52high': 624,
#    'week52low': 427,
#    'week52highSplitAdjustOnly': 624,
#    'week52highDateSplitAdjustOnly': '2021-12-06',
#    'week52lowSplitAdjustOnly': 440.91,
#    'week52lowDateSplitAdjustOnly': '2022-02-03',
#    'week52change': -0.10949609444690324,
#    'sharesOutstanding': 55374888,
#    'float': None,
#    'avg10Volume': 727371,
#    'avg30Volume': 579202,
#    'day200MovingAvg': 563.09,
#    'day50MovingAvg': 529.5,
#    'employees': 8885,
#    'ttmEPS': 32.03,
#    'ttmDividendRate': None,
#    'dividendYield': None,
#    'nextDividendDate': None,
#    'exDividendDate': None,
#    'nextEarningsDate': '2022-04-28',
#    'peRatio': 14.00852704631085,
#    'maxChangePercent': 11.944823594779281,
#    'year5ChangePercent': 4.178907746039016,
#    'year2ChangePercent': 0.8243159046481066,
#    'year1ChangePercent': -0.09150128354709601,
#    'ytdChangePercent': -0.28040796869941115,
#    'month6ChangePercent': -0.24219384058798782,
#    'month3ChangePercent': -0.2736864446454039,
#    'month1ChangePercent': -0.18411171976904675,
#    'day30ChangePercent': -0.1827352395286488,
#    'day5ChangePercent': -0.11607246639684288},
#   'quote': {'avgTotalVolume': 565430,
#    'calculationPrice': 'close',
#    'change': 8.69,
#    'changePercent': 0.02039,
#    'close': 0,
#    'closeSource': 'afcoflii',
#    'closeTime': None,
#    'companyName': 'Zebra Technologies Corp. - Class A',
#    'currency': 'USD',
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPrice': None,
#    'extendedPriceTime': None,
#    'high': 0,
#    'highSource': None,
#    'highTime': None,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexClose': 444.3,
#    'iexCloseTime': 1682816048746,
#    'iexLastUpdated': 0,
#    'iexMarketPercent': None,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexRealtimePrice': 0,
#    'iexRealtimeSize': 0,
#    'iexVolume': 0,
#    'lastTradeTime': 1657389819091,
#    'latestPrice': 438.58,
#    'latestSource': 'Close',
#    'latestTime': 'February 15, 2022',
#    'latestUpdate': 1664764225626,
#    'latestVolume': None,
#    'low': 0,
#    'lowSource': None,
#    'lowTime': None,
#    'marketCap': 23202513159,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'open': 0,
#    'openTime': None,
#    'openSource': 'ociiaflf',
#    'peRatio': 14.49,
#    'previousClose': 440.4,
#    'previousVolume': 675758,
#    'primaryExchange': 'DNSQAA',
#    'symbol': 'ZBRA',
#    'volume': None,
#    'week52High': 639,
#    'week52Low': 441.72,
#    'ytdChange': -0.25081394418896047,
#    'isUSMarketOpen': False}},
#  'ZION': {'advanced-stats': {'beta': 1.103280409652337,
#    'totalCash': None,
#    'currentDebt': 79820458572,
#    'revenue': 3593587226,
#    'grossProfit': 3940465509,
#    'totalRevenue': 3597035027,
#    'EBITDA': 2146852832,
#    'revenuePerShare': 23,
#    'revenuePerEmployee': 351985.61,
#    'debtToEquity': 11.466267730066328,
#    'profitMargin': 0.4998956257357441,
#    'enterpriseValue': 11876554855,
#    'enterpriseValueToRevenue': 3.46,
#    'priceToSales': 3.38,
#    'priceToBook': 1.63,
#    'forwardPERatio': 15.196008175544398,
#    'pegRatio': 0.019717700220333728,
#    'peHigh': 11.661700973869944,
#    'peLow': 8.471673985815311,
#    'week52highDate': '2022-01-31',
#    'week52lowDate': '2021-07-14',
#    'putCallRatio': None,
#    'companyName': 'Zions Bancorporation N.A',
#    'marketcap': 11838038625,
#    'week52high': 78.18,
#    'week52low': 46.38,
#    'week52highSplitAdjustOnly': 76.91,
#    'week52highDateSplitAdjustOnly': '2022-01-27',
#    'week52lowSplitAdjustOnly': 47.59,
#    'week52lowDateSplitAdjustOnly': '2021-07-07',
#    'week52change': 0.5001213238994122,
#    'sharesOutstanding': 163993061,
#    'float': None,
#    'avg10Volume': 1682200,
#    'avg30Volume': 1784557,
#    'day200MovingAvg': 63.5,
#    'day50MovingAvg': 70.49,
#    'employees': 9900,
#    'ttmEPS': 10.6,
#    'ttmDividendRate': 1.47508531358069,
#    'dividendYield': 0.01981059937346027,
#    'nextDividendDate': None,
#    'exDividendDate': '2022-02-10',
#    'nextEarningsDate': '2022-04-14',
#    'peRatio': 7.018707409572996,
#    'maxChangePercent': 0.5733792785403526,
#    'year5ChangePercent': 0.5794038612192024,
#    'year2ChangePercent': 0.6971514310333201,
#    'year1ChangePercent': 0.5619695986206522,
#    'ytdChangePercent': 0.1782564471593673,
#    'month6ChangePercent': 0.3584351408104338,
#    'month3ChangePercent': 0.12354158818428167,
#    'month1ChangePercent': 0.052518243565713676,
#    'day30ChangePercent': 0.05350680306657479,
#    'day5ChangePercent': 0.004784502163404518},
#   'quote': {'avgTotalVolume': 1773886,
#    'calculationPrice': 'close',
#    'change': 2,
#    'changePercent': 0.02713,
#    'close': 0,
#    'closeSource': 'coflaiif',
#    'closeTime': None,
#    'companyName': 'Zions Bancorporation N.A',
#    'currency': 'USD',
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPrice': None,
#    'extendedPriceTime': None,
#    'high': 0,
#    'highSource': None,
#    'highTime': None,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexClose': 75.92,
#    'iexCloseTime': 1701771710420,
#    'iexLastUpdated': 0,
#    'iexMarketPercent': None,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexRealtimePrice': 0,
#    'iexRealtimeSize': 0,
#    'iexVolume': 0,
#    'lastTradeTime': 1645614851782,
#    'latestPrice': 75.66,
#    'latestSource': 'Close',
#    'latestTime': 'February 15, 2022',
#    'latestUpdate': 1702173941395,
#    'latestVolume': None,
#    'low': 0,
#    'lowSource': None,
#    'lowTime': None,
#    'marketCap': 11824549809,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'open': 0,
#    'openTime': None,
#    'openSource': 'icffolia',
#    'peRatio': 7.21,
#    'previousClose': 73.7,
#    'previousVolume': 2118352,
#    'primaryExchange': 'SANQAD',
#    'symbol': 'ZION',
#    'volume': None,
#    'week52High': 75.22,
#    'week52Low': 47.05,
#    'ytdChange': 0.2101541951385164,
#    'isUSMarketOpen': False}},
#  'ZTS': {'advanced-stats': {'beta': 0.8704937183438356,
#    'totalCash': 3274546385,
#    'currentDebt': 1502756480,
#    'revenue': 7938976511,
#    'grossProfit': 5317221749,
#    'totalRevenue': 7690801754,
#    'EBITDA': 2906332996,
#    'revenuePerShare': 16.5,
#    'revenuePerEmployee': 848121.82,
#    'debtToEquity': 3.033968022371606,
#    'profitMargin': 0.2707639067674897,
#    'enterpriseValue': 98353048834,
#    'enterpriseValueToRevenue': 13.06,
#    'priceToSales': 12.34,
#    'priceToBook': 21,
#    'forwardPERatio': 39.51620613125296,
#    'pegRatio': 2.431387617948893,
#    'peHigh': 78.77531324023217,
#    'peLow': 57.97935274108116,
#    'week52highDate': '2021-12-17',
#    'week52lowDate': '2021-03-02',
#    'putCallRatio': 1.216067251785933,
#    'companyName': 'Zoetis Inc',
#    'marketcap': 97844983277,
#    'week52high': 258.42,
#    'week52low': 146.26,
#    'week52highSplitAdjustOnly': 257.65,
#    'week52highDateSplitAdjustOnly': '2021-12-30',
#    'week52lowSplitAdjustOnly': 144.14,
#    'week52lowDateSplitAdjustOnly': '2021-02-28',
#    'week52change': 0.1963152679209758,
#    'sharesOutstanding': 477420556,
#    'float': None,
#    'avg10Volume': 3189511,
#    'avg30Volume': 2959337,
#    'day200MovingAvg': 217.09,
#    'day50MovingAvg': 216.28,
#    'employees': 11484,
#    'ttmEPS': 4.24,
#    'ttmDividendRate': 1.0766170521364156,
#    'dividendYield': 0.005695456315742186,
#    'nextDividendDate': '2022-04-17',
#    'exDividendDate': '',
#    'nextEarningsDate': None,
#    'peRatio': 47.89155707131362,
#    'maxChangePercent': 5.804174356281,
#    'year5ChangePercent': 2.755453576504269,
#    'year2ChangePercent': 0.401633316365986,
#    'year1ChangePercent': 0.2013441342219883,
#    'ytdChangePercent': -0.19399740453734868,
#    'month6ChangePercent': -0.016259762062751794,
#    'month3ChangePercent': -0.0857124072802958,
#    'month1ChangePercent': -0.04095102873599821,
#    'day30ChangePercent': -0.03932516305418741,
#    'day5ChangePercent': -0.01820115617228049},
#   'quote': {'avgTotalVolume': 3030120,
#    'calculationPrice': 'close',
#    'change': 1.33,
#    'changePercent': 0.00708,
#    'close': 0,
#    'closeSource': 'oaciffil',
#    'closeTime': None,
#    'companyName': 'Zoetis Inc - Class A',
#    'currency': 'USD',
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPrice': None,
#    'extendedPriceTime': None,
#    'high': 0,
#    'highSource': '5teidp 1neidcym aeue rl',
#    'highTime': 1691614154338,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexClose': 199.01,
#    'iexCloseTime': 1656076766584,
#    'iexLastUpdated': 0,
#    'iexMarketPercent': None,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexRealtimePrice': 0,
#    'iexRealtimeSize': 0,
#    'iexVolume': 0,
#    'lastTradeTime': 1690823778280,
#    'latestPrice': 204,
#    'latestSource': 'Close',
#    'latestTime': 'February 15, 2022',
#    'latestUpdate': 1687181186599,
#    'latestVolume': None,
#    'low': 0,
#    'lowSource': 'd5aeen  liptem1idue ryc',
#    'lowTime': 1696089005662,
#    'marketCap': 93799771610,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'open': 0,
#    'openTime': None,
#    'openSource': 'lffiacio',
#    'peRatio': 48.28,
#    'previousClose': 204.29,
#    'previousVolume': 3530114,
#    'primaryExchange': '.YWCINCCERKNEOGT  XHNEKS O A',
#    'symbol': 'ZTS',
#    'volume': None,
#    'week52High': 251.16,
#    'week52Low': 141.78,
#    'ytdChange': -0.18734332151004587,
#    'isUSMarketOpen': False}}}

# %%
rv_cols = ["Ticker",
           "Price",
           "Number of shares to buy",
           "Price-to-Earnings Ratio",
           "PE Percentile",
           "Price-to-Book Ratio",
           "PB Percentile",
           "Price-to-Sales Ratio",
           "PS Percentile",
           "EV/EBITDA",
           "EV/EBITDA Percentile",
           "EV/GP",
           "EV/GP Percentile",
           "RV Score"
          ]

# %%
rv_dataframe = pd.DataFrame(columns = rv_cols)
rv_dataframe

def try_division(val1, val2):
    try:
        x = val1/val2
        return x
    except TypeError:
        return np.NaN

# %%
for symbol_string in symbol_strings:
    batch_api_call_url = f"{base_url}market/batch?symbols={symbol_string}&types=quote,advanced-stats&token={IEX_CLOUD_API_TOKEN}"
    data = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        if symbol == "WLTW":
            continue
        
        ev = data[symbol]["advanced-stats"]["enterpriseValue"]
        EBITDA = data[symbol]["advanced-stats"]["EBITDA"]
        gp = data[symbol]["advanced-stats"]["grossProfit"]
        rv_dataframe = rv_dataframe.append(
            pd.Series(
                [
                    symbol,
                    data[symbol]["quote"]["latestPrice"],
                    'N/A',
                    data[symbol]["quote"]["peRatio"],
                    'N/A',
                    data[symbol]["advanced-stats"]["priceToBook"],
                    'N/A',
                    data[symbol]["advanced-stats"]["priceToSales"],
                    'N/A',
                    try_division(ev, EBITDA),
                    'N/A',
                    try_division(ev, gp),
                    'N/A',
                    'N/A'
                ],
                index = rv_cols
            ),
            ignore_index = True
        )

# %%
rv_dataframe
# Out:
#     Ticker   Price Number of shares to buy Price-to-Earnings Ratio  \
# 0        A  141.26                     N/A                   17.29
# 1      AAL   19.40                     N/A                   -3.76
# 2      AAP  225.80                     N/A                   22.87
# 3     AAPL  174.27                     N/A                    28.7
# 4     ABBV  151.42                     N/A                   35.48
# ..     ...     ...                     ...                     ...
# 499    YUM  124.00                     N/A                   24.02
# 500    ZBH  125.57                     N/A                   32.14
# 501   ZBRA  437.19                     N/A                   13.96
# 502   ZION   74.66                     N/A                    7.18
# 503    ZTS  198.82                     N/A                   49.71
#
#     PE Percentile Price-to-Book Ratio PB Percentile Price-to-Sales Ratio  \
# 0             N/A                3.84           N/A                 3.37
# 1             N/A               -1.67           N/A               0.5163
# 2             N/A                4.35           N/A                 1.31
# 3             N/A                41.0           N/A                 7.73
# 4             N/A               18.91           N/A                 4.73
# ..            ...                 ...           ...                  ...
# 499           N/A               -4.77           N/A                  5.8
# 500           N/A                2.07           N/A                 3.39
# 501           N/A                   4           N/A                 2.09
# 502           N/A                1.59           N/A                 3.39
# 503           N/A                  20           N/A                12.66
#
#     PS Percentile  EV/EBITDA EV/EBITDA Percentile      EV/GP EV/GP Percentile  \
# 0             N/A  12.465691                  N/A   6.290456              N/A
# 1             N/A  -7.491240                  N/A   1.504951              N/A
# 2             N/A  12.782130                  N/A   2.882481              N/A
# 3             N/A  23.294605                  N/A  18.096361              N/A
# 4             N/A  11.994231                  N/A   8.644275              N/A
# ..            ...        ...                  ...        ...              ...
# 499           N/A  20.704780                  N/A   9.835312              N/A
# 500           N/A  18.305294                  N/A   5.985035              N/A
# 501           N/A  11.191231                  N/A   4.598742              N/A
# 502           N/A   5.728446                  N/A   2.988316              N/A
# 503           N/A  32.853088                  N/A  18.143357              N/A
#
#     RV Score
# 0        N/A
# 1        N/A
# 2        N/A
# 3        N/A
# 4        N/A
# ..       ...
# 499      N/A
# 500      N/A
# 501      N/A
# 502      N/A
# 503      N/A
#
# [504 rows x 14 columns]

# %%
for column in ['Price-to-Earnings Ratio', 'Price-to-Book Ratio', 
              'Price-to-Sales Ratio', 'EV/EBITDA',
              'EV/GP']:
    rv_dataframe[column].fillna(rv_dataframe[column].mean(), inplace=True)

# %%
metrics = {           
           "Price-to-Earnings Ratio" : "PE Percentile",
           "Price-to-Book Ratio" : "PB Percentile",
           "Price-to-Sales Ratio" : "PS Percentile",
           "EV/EBITDA" : "EV/EBITDA Percentile",
           "EV/GP" : "EV/GP Percentile",
}

# %%
for metric in metrics.keys():
    for row in rv_dataframe.index:
        rv_dataframe.loc[row, metrics[metric]] = (stats.percentileofscore(rv_dataframe[metric], rv_dataframe.loc[row, metric]))/100

# %%
rv_dataframe
# Out:
#     Ticker   Price Number of shares to buy  Price-to-Earnings Ratio  \
# 0        A  141.26                     N/A                    17.29
# 1      AAL   19.40                     N/A                    -3.76
# 2      AAP  225.80                     N/A                    22.87
# 3     AAPL  174.27                     N/A                    28.70
# 4     ABBV  151.42                     N/A                    35.48
# ..     ...     ...                     ...                      ...
# 499    YUM  124.00                     N/A                    24.02
# 500    ZBH  125.57                     N/A                    32.14
# 501   ZBRA  437.19                     N/A                    13.96
# 502   ZION   74.66                     N/A                     7.18
# 503    ZTS  198.82                     N/A                    49.71
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0        0.405754                 3.84      0.579365                3.3700
# 1        0.051587                -1.67       0.05754                0.5163
# 2         0.53869                 4.35      0.668651                1.3100
# 3        0.666667                41.00      0.974206                7.7300
# 4        0.781746                18.91      0.936508                4.7300
# ..            ...                  ...           ...                   ...
# 499      0.565476                -4.77      0.051587                5.8000
# 500      0.734127                 2.07      0.338294                3.3900
# 501      0.315476                 4.00         0.625                2.0900
# 502      0.132937                 1.59      0.232143                3.3900
# 503      0.878968                20.00      0.940476               12.6600
#
#     PS Percentile  EV/EBITDA EV/EBITDA Percentile      EV/GP EV/GP Percentile  \
# 0        0.537698  12.465691             0.458333   6.290456         0.490079
# 1        0.063492  -7.491240             0.019841   1.504951          0.06746
# 2        0.246032  12.782130             0.472222   2.882481         0.172619
# 3        0.873016  23.294605             0.805556  18.096361          0.93254
# 4        0.734127  11.994231             0.436508   8.644275         0.690476
# ..            ...        ...                  ...        ...              ...
# 499       0.80754  20.704780                 0.75   9.835312         0.744048
# 500      0.546627  18.305294             0.668651   5.985035         0.462302
# 501      0.390873  11.191231              0.39881   4.598742         0.331349
# 502      0.546627   5.728446             0.107143   2.988316         0.180556
# 503       0.94246  32.853088              0.89881  18.143357         0.936508
#
#     RV Score
# 0        N/A
# 1        N/A
# 2        N/A
# 3        N/A
# 4        N/A
# ..       ...
# 499      N/A
# 500      N/A
# 501      N/A
# 502      N/A
# 503      N/A
#
# [504 rows x 14 columns]

# %%
from statistics import mean

# %%
for row in rv_dataframe.index:
    percentiles = []
    for metric in metrics.keys():
        percentiles.append(rv_dataframe.loc[row, metrics[metric]])
    rv_dataframe.loc[row, "RV Score"] = mean(percentiles)

# %%
rv_dataframe.sort_values("RV Score", ascending=True, inplace = True)
rv_dataframe = rv_dataframe[:50]
rv_dataframe.reset_index(drop=True, inplace=True)

# %%
rv_dataframe
# Out:
#    Ticker   Price Number of shares to buy  Price-to-Earnings Ratio  \
# 0       F   18.69                     N/A                     2.07
# 1      GM   50.15                     N/A                     3.80
# 2     AAL   19.40                     N/A                    -3.76
# 3     HPQ   37.81                     N/A                     3.68
# 4     UNM   30.88                     N/A                     7.66
# 5       L   63.98                     N/A                     5.18
# 6     SYF   44.94                     N/A                     3.19
# 7     PHM   49.60                     N/A                     3.44
# 8     PRU  120.00                     N/A                     6.57
# 9     PFG   79.25                     N/A                     6.22
# 10    LEN   94.79                     N/A                     3.24
# 11    WHR  212.37                     N/A                     3.76
# 12    CVS  104.87                     N/A                     8.70
# 13    DOW   62.34                     N/A                     3.72
# 14    HPE   17.73                     N/A                     3.46
# 15    AIG   63.29                     N/A                     9.61
# 16    AIZ  172.80                     N/A                     7.71
# 17    ALL  125.93                     N/A                    11.51
# 18    KSS   62.59                     N/A                     9.39
# 19  CMCSA   49.04                     N/A                     8.20
# 20   INTC   49.05                     N/A                     5.12
# 21    MET   73.11                     N/A                    12.36
# 22    LNC   76.34                     N/A                    10.89
# 23      C   67.00                     N/A                     6.77
# 24   VIAC   37.51                     N/A                     7.00
# 25   ANTM  457.71                     N/A                     9.10
# 26    WBA   50.20                     N/A                     6.71
# 27     VZ   55.25                     N/A                     5.26
# 28    BKR   29.45                     N/A                   -55.17
# 29    USB   59.54                     N/A                     5.82
# 30    DXC   37.94                     N/A                   -15.81
# 31    OMC   87.96                     N/A                     6.65
# 32    UAL   51.65                     N/A                    -5.02
# 33    GPS   15.59                     N/A                    12.14
# 34    NRG   40.77                     N/A                     4.08
# 35    HFC   38.41                     N/A                    13.35
# 36    TAP   51.09                     N/A                   -25.29
# 37    HIG   73.01                     N/A                    11.93
# 38     GS  367.10                     N/A                     6.20
# 39    SNA  217.23                     N/A                     7.28
# 40    MHK  152.89                     N/A                     9.56
# 41   PRGO   39.89                     N/A                   -20.69
# 42    COF  162.56                     N/A                     5.96
# 43     GE  103.73                     N/A                    -8.50
# 44    BAC   48.93                     N/A                     6.83
# 45   CTVA   51.53                     N/A                    11.19
# 46    CMI  232.38                     N/A                     7.90
# 47    MAS   58.75                     N/A                    18.75
# 48    BEN   31.07                     N/A                     8.20
# 49    HII  185.46                     N/A                     6.91
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0       0.061508               0.7440      0.083333                0.2649
# 1       0.085317               0.6230       0.06746                0.2971
# 2       0.051587              -1.6700       0.05754                0.5163
# 3       0.079365             -12.6700      0.039683                0.3308
# 4       0.138889               0.5441      0.061508                0.4727
# 5       0.097222               0.4392      0.059524                0.5346
# 6       0.065476               0.9379      0.115079                0.7098
# 7       0.073413               0.8515       0.10119                0.4557
# 8       0.113095               0.7555      0.087302                0.6380
# 9       0.111111               0.6311      0.071429                0.7260
# 10       0.06746               0.6626      0.075397                0.5048
# 11      0.083333               1.3000      0.162698                0.2806
# 12      0.168651               0.9251      0.111111                0.2401
# 13      0.081349               1.2700      0.155754                0.4330
# 14      0.075397               0.5647      0.063492                0.4243
# 15       0.19246               0.8106      0.093254                1.0600
# 16      0.142857               1.7000      0.267857                0.9318
# 17          0.25               1.4600      0.208333                0.7370
# 18       0.18254               1.7000      0.267857                0.4360
# 19       0.15873               1.1600      0.142857                0.9687
# 20      0.095238               1.0800      0.130952                1.3100
# 21      0.265873               0.8755      0.105159                0.8925
# 22      0.232143               0.6374      0.073413                0.7042
# 23      0.121032               0.7482      0.085317                1.7500
# 24      0.130952               1.1900      0.145833                0.9100
# 25      0.174603               1.5600      0.229167                0.4026
# 26      0.119048               1.6600          0.25                0.3233
# 27      0.099206               1.3800       0.18254                0.8426
# 28      0.017857               1.0000      0.119048                0.7525
# 29      0.103175               0.9145      0.109127                1.9100
# 30      0.039683               1.9500       0.31746                0.5588
# 31      0.117063               2.9300      0.460317                0.6603
# 32      0.047619               3.0500       0.47619                0.8303
# 33      0.263889               2.1300      0.357143                0.3662
# 34      0.087302               2.3900      0.388889                0.4493
# 35      0.295635               1.1100      0.138889                0.3991
# 36      0.027778               0.8323      0.099206                1.0900
# 37      0.257937               1.4000       0.19246                1.1000
# 38      0.109127               1.3200      0.169643                1.9100
# 39      0.134921               1.4500      0.204365                1.2700
# 40      0.190476               1.2100      0.152778                0.9121
# 41      0.029762               1.0170      0.123016                1.2200
# 42      0.105159               1.0700      0.125992                2.1800
# 43      0.045635               1.3900      0.186508                0.7773
# 44      0.123016               0.8230      0.097222                2.1200
# 45      0.244048               0.7630      0.089286                1.2300
# 46      0.146825               1.9400      0.315476                0.6794
# 47      0.436508             -40.2500      0.021825                0.8323
# 48       0.15873               1.4100      0.197421                1.8000
# 49      0.127976               1.3400      0.176587                0.3852
#
#    PS Percentile  EV/EBITDA EV/EBITDA Percentile     EV/GP EV/GP Percentile  \
# 0       0.013889   1.739571              0.02381  0.934564         0.037698
# 1       0.017857   1.099285             0.021825  0.957072         0.039683
# 2       0.063492  -7.491240             0.019841  1.504951          0.06746
# 3       0.021825   4.074617             0.051587  1.764920         0.089286
# 4       0.051587   3.704399             0.045635  0.442502         0.005952
# 5       0.065476   3.717844             0.047619  0.967452         0.041667
# 6       0.099206   2.049777             0.025794  0.734151         0.025794
# 7       0.047619   2.427437             0.029762  1.695504         0.085317
# 8       0.079365   4.798948             0.073413  0.641268         0.015873
# 9       0.105159   4.310637             0.063492  0.713190         0.021825
# 10      0.059524   2.828572              0.03373  2.802055         0.166667
# 11      0.015873   3.584702             0.039683  1.912670         0.107143
# 12      0.009921   5.927568             0.115079  0.978663         0.043651
# 13      0.041667   3.585764             0.041667  3.195319         0.196429
# 14      0.039683   7.866645              0.22619  2.115374         0.119048
# 15      0.172619   4.573640             0.069444  1.051416         0.047619
# 16      0.144841   2.062549             0.027778  0.921676         0.035714
# 17      0.107143   2.468150             0.031746  0.733139          0.02381
# 18      0.043651   4.459853              0.06746  1.371442         0.063492
# 19      0.156746   5.361537             0.089286  1.689159         0.083333
# 20      0.246032   3.174288             0.035714  2.375844         0.142857
# 21      0.136905   6.226686             0.136905  0.891088         0.031746
# 22      0.097222   8.188163             0.255952  0.681765         0.017857
# 23      0.333333   4.183470             0.059524  1.687621         0.081349
# 24      0.138889   7.614708             0.204365  1.343930         0.061508
# 25       0.03373   8.230234             0.257937  0.601640         0.011905
# 26      0.019841   7.839505             0.220238  1.846032         0.099206
# 27      0.128968   5.353185             0.087302  3.416360         0.220238
# 28      0.109127   6.869414              0.15873  4.450974         0.315476
# 29      0.360119   4.181641              0.05754  1.778366          0.09127
# 30      0.069444   5.594632             0.099206  3.208120         0.198413
# 31      0.087302   4.045194             0.049603  0.689508         0.019841
# 32      0.123016  -8.235924             0.017857  1.590421         0.073413
# 33       0.02381   4.231963             0.061508  0.913630          0.03373
# 34      0.045635   3.690055             0.043651  2.939014         0.176587
# 35      0.031746   6.207903             0.132937  2.587073         0.152778
# 36      0.178571   7.161205             0.174603  4.240288         0.285714
# 37      0.185516   5.484889             0.095238  1.145297         0.051587
# 38      0.360119   4.085976             0.053571  1.848501          0.10119
# 39      0.230159   4.917500             0.079365  2.577516         0.150794
# 40      0.142857   5.734675             0.109127  3.332526         0.212302
# 41      0.213294   6.714594             0.150794  4.320963         0.291667
# 42       0.41369   4.148952             0.055556  2.016485         0.113095
# 43      0.111111   9.386979             0.309524  3.090666         0.186508
# 44       0.39881   5.854050             0.113095  1.959995         0.109127
# 45       0.21627   7.113693             0.172619  2.262616         0.136905
# 46      0.089286   6.150245             0.126984  3.033443          0.18254
# 47         0.125   5.671522             0.103175  3.276482         0.202381
# 48      0.342262   5.985868             0.119048  1.679845         0.079365
# 49      0.027778   7.954623             0.236111  4.680863         0.345238
#
#     RV Score
# 0   0.044048
# 1   0.046429
# 2   0.051984
# 3   0.056349
# 4   0.060714
# 5   0.062302
# 6    0.06627
# 7    0.06746
# 8    0.07381
# 9   0.074603
# 10  0.080556
# 11  0.081746
# 12  0.089683
# 13  0.103373
# 14  0.104762
# 15  0.115079
# 16   0.12381
# 17  0.124206
# 18     0.125
# 19   0.12619
# 20  0.130159
# 21  0.135317
# 22  0.135317
# 23  0.136111
# 24   0.13631
# 25  0.141468
# 26  0.141667
# 27  0.143651
# 28  0.144048
# 29  0.144246
# 30  0.144841
# 31  0.146825
# 32  0.147619
# 33  0.148016
# 34  0.148413
# 35  0.150397
# 36  0.153175
# 37  0.156548
# 38   0.15873
# 39  0.159921
# 40  0.161508
# 41  0.161706
# 42  0.162698
# 43  0.167857
# 44  0.168254
# 45  0.171825
# 46  0.172222
# 47  0.177778
# 48  0.179365
# 49  0.182738

# %%
portfolio_input()
# Out:
# Please enter your portfolio size10000000

# %%
position_size = portfolio_size/rv_dataframe.shape[0]

# %%
for row in rv_dataframe.index:
    rv_dataframe.loc[row, "Number of shares to buy"] = math.floor(position_size/rv_dataframe.loc[row, "Price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
writer = pd.ExcelWriter("value strategy.xlsx", engine="xlsxwriter")
rv_dataframe.to_excel(writer, "Value Strategy", index = False)

# %%
background_color = "0a0a23"
font_color = "#ffffff"

string_format = writer.book.add_format(
    {
        "font_color": font_color,
        "bg_color": background_color,
        "border": 1
    }
)

dollar_format = writer.book.add_format(
    {
        "num_format": "$0.00",
        "font_color": font_color,
        "bg_color": background_color,
        "border": 1
    }
)

number_format = writer.book.add_format(
    {
        "num_format": "0",
        "font_color": font_color,
        "bg_color": background_color,
        "border": 1
    }
)

float_format = writer.book.add_format(
    {
        "num_format": "0.0",
        "font_color": font_color,
        "bg_color": background_color,
        "border": 1
    }
)

percent_format = writer.book.add_format(
    {
        "num_format": "0.0%",
        "font_color": font_color,
        "bg_color": background_color,
        "border": 1
    }
)

# %%
column_formats = {
         "A" : ["Ticker", string_format],
         "B" : ["Price", dollar_format],
         "C" : ["Number of shares to buy", number_format],
         "D" : ["Price-to-Earnings Ratio", float_format],
         "E" : ["PE Percentile", percent_format],
         "F" : ["Price-to-Book Ratio", float_format],
         "G" : ["PB Percentile", percent_format],
         "H" : ["Price-to-Sales Ratio", float_format],
         "I" : ["PS Percentile", percent_format],
         "J" : ["EV/EBITDA", float_format],
         "K" : ["EV/EBITDA Percentile", percent_format],
         "L" : ["EV/GP", float_format],
         "M" : ["EV/GP Percentile", percent_format],
         "N" : ["RV Score", percent_format]
}

# %%
for column in column_formats.keys():
    writer.sheets["Value Strategy"].set_column(f"{column}:{column}", 25, column_formats[column][1])
    writer.sheets["Value Strategy"].write(f"{column}1", column_formats[column][0], column_formats[column][1])

# %%
writer.save()
